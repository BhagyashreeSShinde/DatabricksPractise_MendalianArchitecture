-- %%
GRANT READ FILES, WRITE FILES,
      CREATE EXTERNAL TABLE, CREATE EXTERNAL VOLUME
  ON EXTERNAL LOCATION saleslake_ext
  TO `account users`;

GRANT BROWSE
  ON EXTERNAL LOCATION saleslake_ext
  TO `account users`;


SHOW GRANTS ON EXTERNAL LOCATION saleslake_ext;
