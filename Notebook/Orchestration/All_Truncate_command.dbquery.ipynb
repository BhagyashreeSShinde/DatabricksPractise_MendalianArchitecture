-- %%
-------------------- 1. Bronze Tables -------------------------
-- Bronze Sales
TRUNCATE TABLE saleslake_dev.bronze_dev.rawsales;
TRUNCATE TABLE saleslake_qa.bronze_qa.rawsales;
TRUNCATE TABLE saleslake_prd.bronze_prd.rawsales;

-- Bronze Customer
TRUNCATE TABLE saleslake_dev.bronze_dev.rawCustomer;
TRUNCATE TABLE saleslake_qa.bronze_qa.rawCustomer;
TRUNCATE TABLE saleslake_prd.bronze_prd.rawCustomer;



--------------------- 2. Silver Tables -------------------------
-- Silver Sales
TRUNCATE TABLE saleslake_dev.silver_dev.cleanedsales;
TRUNCATE TABLE saleslake_qa.silver_qa.cleanedsales;
TRUNCATE TABLE saleslake_prd.silver_prd.cleanedsales;

-- Silver Customer
TRUNCATE TABLE saleslake_dev.silver_dev.cleanedcustomer;
TRUNCATE TABLE saleslake_qa.silver_qa.cleanedcustomer;
TRUNCATE TABLE saleslake_prd.silver_prd.cleanedcustomer;

--------------------- 3. Gold Tables -------------------------
-- Gold Sales
TRUNCATE TABLE saleslake_dev.gold_dev.RefinedSales;
TRUNCATE TABLE saleslake_qa.gold_qa.RefinedSales;
TRUNCATE TABLE saleslake_prd.gold_prd.RefinedSales;

-- Gold Customer
TRUNCATE TABLE saleslake_dev.gold_dev.refinedcustomer;   
TRUNCATE TABLE saleslake_qa.gold_qa.refinedcustomer;
TRUNCATE TABLE saleslake_prd.gold_prd.refinedcustomer;
--********************************DELETE COMMANDS*************************************
-------------------- 1. Bronze Tables -------------------------
-- Bronze Sales
DROP TABLE saleslake_dev.bronze_dev.rawsales;
DROP TABLE saleslake_qa.bronze_qa.rawsales;
DROP TABLE saleslake_prd.bronze_prd.rawsales;

-- Bronze Customer
DROP TABLE saleslake_dev.bronze_dev.rawCustomer;
DROP TABLE saleslake_qa.bronze_qa.rawCustomer;
DROP TABLE saleslake_prd.bronze_prd.rawCustomer;



--------------------- 2. Silver Tables -------------------------
-- Silver Sales
DROP TABLE saleslake_dev.silver_dev.cleanedsales;
DROP TABLE saleslake_qa.silver_qa.cleanedsales;
DROP TABLE saleslake_prd.silver_prd.cleanedsales;

-- Silver Customer
DROP TABLE saleslake_dev.silver_dev.cleanedcustomer;
DROP TABLE saleslake_qa.silver_qa.cleanedcustomer;
DROP TABLE saleslake_prd.silver_prd.cleanedcustomer;

--------------------- 3. Gold Tables -------------------------
-- Gold Sales
DROP TABLE saleslake_dev.gold_dev.RefinedSales;
DROP TABLE saleslake_qa.gold_qa.RefinedSales;
DROP TABLE saleslake_prd.gold_prd.RefinedSales;

-- Gold Customer
DROP TABLE saleslake_dev.gold_dev.refinedcustomer;   
DROP TABLE saleslake_qa.gold_qa.refinedcustomer;
DROP TABLE saleslake_prd.gold_prd.refinedcustomer;
