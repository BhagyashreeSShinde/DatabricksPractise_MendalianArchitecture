-- %%
%python
# Source Files Directories
dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_dev/bronze_dev/vol_saleslake_src_files_dev/dailyCustomer/")
dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_dev/bronze_dev/vol_saleslake_src_files_dev/daily_sales/")

-- %%
%python
dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_dev/bronze_dev/vol_saleslake_archive_files_dev/dailyCustomer/")
dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_dev/bronze_dev/vol_saleslake_archive_files_dev/daily_sales/")

-- %%
%python

src ='/Volumes/saleslake_dev/bronze_dev/vol_saleslake_src_files_dev/dailyCustomer/'
arc= '/Volumes/saleslake_dev/bronze_dev/vol_saleslake_archive_files_dev/dailyCustomer/'
listOfFiles=dbutils.fs.ls(src)
print(listOfFiles)

-- %%
%python
dbutils.fs.mv(src,arc,recurse=True)

-- %%
%python
src ='/Volumes/saleslake_dev/bronze_dev/vol_saleslake_src_files_dev/dailyCustomer/'
arc= '/Volumes/saleslake_dev/bronze_dev/vol_saleslake_archive_files_dev/dailyCustomer/'
listOfFiles=dbutils.fs.ls(src)
#print(listOfFiles)
for file in listOfFiles:
  print(file.name)
  if file.name.endswith('csv'):
    dbutils.fs.mv(src+file.name,arc+file.name)

-- %%
-- dbutils.fs.cp
-- dbutils.fs.head
-- dbutils.fs.tail
