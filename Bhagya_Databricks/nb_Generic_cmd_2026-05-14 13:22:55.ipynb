# %%
# %sql
USE CATALOG bhagya_databricks;
USE SCHEMA intellibi_databricks_practice;

# %%
# %sql
SHOW CATALOGS

# %%
# %sql
SELECT current_catalog() AS current_catalog, current_schema() AS current_schema

# %%
# %sql
CREATE TABLE IF NOT EXISTS SCHEMA_TEST
(
    id int,
    name STRING


);
