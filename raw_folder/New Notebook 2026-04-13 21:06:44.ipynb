# %%
spark.read.table("samples.bakehouse.sales_franchises").show()

# %%
# ## print("PySpark is very easy to learn")

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Spark DataFrames").getOrCreate()

# %%
spark
