-- %%
CREATE TABLE bhagya_databricks.intellibi_databricks_practice.EMPLOYEE (id INT, name STRING, salary INT);


INSERT INTO bhagya_databricks.intellibi_databricks_practice.EMPLOYEE VALUES (1, 'John', 50000), (2, 'Jane', 60000), (3, 'Bob', 90000);


SELECT * FROM bhagya_databricks.intellibi_databricks_practice.EMPLOYEE;
-- Out:
-- Databricks visualization. Run in Databricks to view.
